# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
housing=pd.read_csv('files/housing.csv')

# %% [markdown]
# 1. General Understanding of data
# 2. Depth understanding of data-- corr(), visualization

# %%
housing_copy= housing.copy()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    s=housing['population'] / 100,  # Scaled down population
    label="population",
    c='median_house_value',
    cmap='jet',
    colorbar=True,
    sharex=False,
    figsize=(10, 8)
)
plt.savefig
# Out:
# <function matplotlib.pyplot.savefig(*args, **kwargs) -> 'None'>
