# %%
import pandas as pd
import numpy as np
from preprocessing import preprocessings

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import cross_val_score

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.metrics import mean_squared_error

# %%
housing = pd.read_csv('files/housing.csv')
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# train test split
housing_train,housing_test=train_test_split(housing,test_size=0.2,stratify=housing['ocean_proximity'],random_state=42)

# %%
# target and feature dataset
x_train=housing_train.drop(['median_house_value'],axis=1)
y_train=housing_train['median_house_value']
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2931     -121.88     38.00                22.0        721.0           117.0
# 4175     -117.82     33.85                18.0       1810.0           305.0
# 12703    -118.31     34.09                34.0       2065.0           839.0
# 16281    -120.76     38.60                14.0       2925.0           625.0
# 12420    -118.09     33.92                36.0        847.0           185.0
# ...          ...       ...                 ...          ...             ...
# 3666     -118.21     34.13                52.0       2465.0           611.0
# 17452    -122.88     38.34                20.0       3404.0           628.0
# 3006     -118.03     33.90                36.0       1143.0           193.0
# 3297     -118.36     34.09                36.0       1390.0           458.0
# 19932    -118.11     33.79                36.0       1993.0           354.0
#
# ...

# %%
random_forest=Pipeline([
    ("preprocessing",preprocessings),
    ("randomforest",RandomForestRegressor(random_state=42))
])

# %%
random_forest.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder=Pipeline(steps=[('impute',
#                                                               SimpleImputer(strategy='median')),
#                                                              ('scale',
#                                                               StandardScaler())]),
#                                    transformers=[('bedrooms',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('ratio',
#                                                                    FunctionTransformer(feature_names_out=<function column_name at 0x000001DFBC57A820>,
#                                                                                        func=<function ratio at 0x0...
# ...

# %%
random_forest.predict(x_train)
# Out:
# array([159251., 225595., 214084., ..., 180980., 226235., 247864.],
#       shape=(16512,))

# %% [markdown]
# #### Fine Tune the Model

# %%
# from sklearn.model_selection import GridSearchCV


# 13 combinations
param_grid=[
    {
    "preprocessing__geo__n_clusters":[12,15], # 2*2 combinations
    "randomforest__max_features":[8,10]
    },
    {
    "preprocessing__geo__n_clusters":[5,8,10], # 3*3 combinations
    "randomforest__max_features":[4,6,8]
    }
    
]

# %%
grid_search=GridSearchCV(
    random_forest,
    param_grid,
    scoring="neg_root_mean_squared_error",
    cv=3,
    refit=True
)

# %%
# hyperparameter Tunning, Parameter Tunning --> fine tune the model
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(remainder=Pipeline(steps=[('impute',
#                                                                                      SimpleImputer(strategy='median')),
#                                                                                     ('scale',
#                                                                                      StandardScaler())]),
#                                                           transformers=[('bedrooms',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('ratio',
# ...

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       13.242047      0.655064         0.487198        0.041130
# 1       17.407604      2.221760         0.447554        0.069923
# 2       12.928248      1.510530         0.383115        0.017755
# 3       14.862081      1.512603         0.377265        0.111118
# 4        7.225958      0.467751         0.309242        0.046916
# 5       10.268210      0.944009         0.296979        0.045316
# 6       13.350013      0.983195         0.506989        0.086618
# 7       10.347901      2.229356         0.475570        0.110725
# 8       16.307512      1.647680         0.469270        0.046968
# 9       21.728634      0.357556         0.556281        0.020080
# 10      11.886707      2.837775         0.502422        0.115921
# 11      16.563841      0.727172         0.477347        0.099505
# 12      12.908804      0.479708         0.398036        0.017286
#
# ...

# %%
grid_search.best_params_
# Out:
# {'preprocessing__geo__n_clusters': 15, 'randomforest__max_features': 8}

# %% [markdown]
# #### GridSearchCV fine for fewer combinations, for higher combinations it is compuatationally expensinve

# %% [markdown]
# ## RandomizedSearchCV for higher
#
# par --> 8 <br>
# space --> 5 <br>
# 8*5

# %%
from scipy.stats import randint

param_distribs={
    "preprocessing__geo__n_clusters":randint(low=3,high=100), # 2*2 combinations
    "randomforest__max_features":randint(low=2,high=20)
    }

# %%
from sklearn.model_selection import RandomizedSearchCV
rnd_search=RandomizedSearchCV(random_forest,
    param_distributions=param_distribs,
    n_iter=10,
    cv=3,
    scoring="neg_root_mean_squared_error",
    random_state=42,
    refit=True
    )

# %%
rnd_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder=Pipeline(steps=[('impute',
#                                                                                            SimpleImputer(strategy='median')),
#                                                                                           ('scale',
#                                                                                            StandardScaler())]),
#                                                                 transformers=[('bedrooms',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('ratio',
# ...

# %%
pd.DataFrame(rnd_search.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      25.175413      7.480692         0.374629        0.093399
# 1      20.580570      0.227287         0.492725        0.008451
# 2      29.382237      0.387892         0.492861        0.019409
# 3      12.500350      0.636589         0.389380        0.090266
# 4      10.384022      1.529005         0.486348        0.007056
# 5       8.821088      0.287225         0.409917        0.118708
# 6      26.491770      2.205712         0.392505        0.021791
# 7       9.985203      3.586526         0.257230        0.087200
# 8       2.582807      0.561711         0.262436        0.103887
# 9      24.027844      1.622959         0.351945        0.120243
#
#    param_preprocessing__geo__n_clusters  param_randomforest__max_features  \
# 0                                    54                                16
# 1                                    74                                 8
# ...

# %%
rnd_search.best_params_
# Out:
# {'preprocessing__geo__n_clusters': 90, 'randomforest__max_features': 13}

# %% [markdown]
# ## Final Model to Launch

# %%
final_model=rnd_search.best_estimator_

# %%
x_train['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7309
# INLAND        5241
# NEAR OCEAN    2126
# NEAR BAY      1832
# ISLAND           4
# Name: count, dtype: int64

# %%
x_df_test=x_train[x_train['ocean_proximity']=="ISLAND"]
y_df_test=y_train[x_train['ocean_proximity']=="ISLAND"]
x_df_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17205    -118.32     33.35                27.0       1675.0           521.0
# 9694     -118.33     33.34                52.0       2359.0           591.0
# 15406    -118.48     33.43                29.0        716.0           214.0
# 10229    -118.32     33.34                52.0        996.0           264.0
#
#        population  households  median_income ocean_proximity
# 17205       744.0       331.0         2.1579          ISLAND
# 9694       1100.0       431.0         2.8333          ISLAND
# 15406       422.0       173.0         2.6042          ISLAND
# 10229       341.0       160.0         2.7361          ISLAND

# %%
pred=final_model.predict(x_df_test)
pred
# Out:
# array([435479.02, 410078.  , 325814.01, 435773.03])

# %%
y_df_test
# Out:
# 17205    450000.0
# 9694     414700.0
# 15406    287500.0
# 10229    450000.0
# Name: median_house_value, dtype: float64

# %% [markdown]
# #### Evaluating model on test set

# %%
x_test=housing_test.drop(['median_house_value'],axis=1)
y_test=housing_test['median_house_value']
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7050     -121.81     38.01                47.0       1942.0           430.0
# 18040    -116.05     33.33                17.0        290.0            94.0
# 19045    -119.76     36.71                29.0       1745.0           441.0
# 2724     -122.25     37.80                42.0       4120.0          1065.0
# 464      -121.98     38.34                18.0       3876.0           916.0
# ...          ...       ...                 ...          ...             ...
# 11702    -124.17     41.76                20.0       2673.0           538.0
# 20128    -122.06     36.98                15.0       3385.0           669.0
# 16143    -122.31     37.94                38.0       2172.0           403.0
# 9591     -122.47     37.69                30.0        837.0           213.0
# 18688    -121.79     37.38                22.0       3650.0           527.0
#
# ...

# %%
pred=final_model.predict(x_test)
pred
# Out:
# array([114117.  ,  68213.  ,  54467.  , ..., 195865.  , 276115.  ,
#        296996.01], shape=(4128,))

# %%
y_test
# Out:
# 7050     105100.0
# 18040     81300.0
# 19045     44400.0
# 2724     225000.0
# 464      129500.0
#            ...
# 11702    105900.0
# 20128    320900.0
# 16143    194200.0
# 9591     258800.0
# 18688    325600.0
# Name: median_house_value, Length: 4128, dtype: float64

# %%
final_mse = mean_squared_error(y_test, pred)
final_rmse=np.sqrt(final_mse)
final_rmse
# Out:
# np.float64(40734.43769312772)

# %% [markdown]
# ### Model Evaluation
# 1. lin_reg ---> 68000 NA
# 2. tree ---> 0.0 ,65000 NA
# 3. forest ---> 17000 --> 46586 --> 40734

# %% [markdown]
# # Approved for Launch

# %% [markdown]
# ### System Improvements Required
# 1. specific error analyse
# 2. add extra feature
# 3. remove uninformative attribute
# 4. outlier, round, cap
