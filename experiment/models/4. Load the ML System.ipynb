# %%
import pandas as pd
import numpy as np
import joblib

# %%
# loading the model
model=joblib.load("HousePricePredictor.pkl")

housing=pd.read_csv('files/housing.csv')
x_test=housing.drop('median_house_value',axis=1)
y_test=housing['median_house_value']
model.predict(x_test)
# Out:
# array([387727.09, 372387.01, 379251.12, ...,  88441.  ,  85451.  ,
#         88797.  ], shape=(20640,))

# %%
y_test
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
# User Interaction
print("provide the details following\n\n")

longitude = float(input("longitude: "))
latitude = float(input("latitude: "))
housing_median_age = int(input("housing_median_age: "))
total_rooms = int(input("total_rooms: "))
total_bedrooms = int(input("total_bedrooms: "))
population = int(input("population: "))
households = int(input("households: "))
median_income = int(input("median_income: "))
ocean_proximity = input("ocean_proximity: ")

# prediction logic
data = [longitude, latitude, housing_median_age, total_rooms,
        total_bedrooms, population, households, median_income,
        ocean_proximity]

clms = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
        'total_bedrooms', 'population', 'households', 'median_income',
        'ocean_proximity']

df = pd.DataFrame([data], columns=clms)

# prediction
result = model.predict(df)

# print the prediction
print(f"\n\t\t This House Should be Around: {result}")
df.info()
# Out:
# provide the details following
#
#
#
# 		 This House Should be Around: [167730.05]
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           1 non-null      float64
#  1   latitude            1 non-null      float64
#  2   housing_median_age  1 non-null      int64
#  3   total_rooms         1 non-null      int64
#  4   total_bedrooms      1 non-null      int64
#  5   population          1 non-null      int64
#  6   households          1 non-null      int64
#  7   median_income       1 non-null      int64
#  8   ocean_proximity     1 non-null      str
# dtypes: float64(2), int64(6), str(1)
# memory usage: 204.0 bytes
